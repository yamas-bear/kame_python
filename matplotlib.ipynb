# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5]
y = np.array(x) ** 2
plt.plot(x,y)

# %%
x = np.linspace(-10,10)
z = 1/(1+np.exp(-x))
plt.plot(x,z)

# %%
df = pd.DataFrame({'x':[1,2,3,4,5,6],'z':[10,12,13,13,16,16]})
plt.plot('x','z',color='pink',data=df,lw=2,ls='--',marker='o',markersize=12,alpha=0.5)

# %%
df = pd.read_csv("dataset/tmdb_5000_movies.csv")

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df = df[(~df['release_date'].isna())]

# %%
df['year'] = df['release_date'].apply(get_year)

# %%
def get_year(release_date):
    return int(release_date[:4])

# %%
df['year']
# Out:
# 0       2009
# 1       2007
# 2       2015
# 3       2012
# 4       2012
#         ...
# 4798    1992
# 4799    2011
# 4800    2013
# 4801    2012
# 4802    2005
# Name: year, Length: 4802, dtype: int64

# %%
plt.plot(df.groupby('year').count()['id'])
plt.xlabel('year')
plt.ylabel('count')
plt.title('Yearly change in the number of movies')
# Out:
# Text(0.5, 1.0, 'Yearly change in the number of movies')

# %%
df = df[df['revenue']!=0]
plt.plot(df.groupby('year').median()['revenue'],label='medisn')

# %%
x = np.linspace(-10,10,100)
plt.subplot(1,2,1)
plt.plot(x,x**2)

plt.subplot(1,2,2)
plt.plot(x,x**3)

# %%
x
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(x,x**2)
ax2.plot(x,np.log(x**2))

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')

# %%
plt.scatter(df['revenue'],df['budget'],alpha=0.2)

# %%
df = df[(df['revenue']!=0) & (df['budget'] !=0)]
lang_group_df = df.groupby('original_language').mean()[['budget','revenue','vote_count']]
plt.scatter('revenue','budget',s='vote_count',data=lang_group_df,c=np.arange(len(lang_group_df)))
for idx,row in lang_group_df.iterrows():
    plt.annotate(idx,(row['revenue'],row['budget']))
